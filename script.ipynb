# %%
pip install requests
# Out:
# Requirement already satisfied: requests in e:\anaconda\lib\site-packages (2.32.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in e:\anaconda\lib\site-packages (from requests) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in e:\anaconda\lib\site-packages (from requests) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in e:\anaconda\lib\site-packages (from requests) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in e:\anaconda\lib\site-packages (from requests) (2025.4.26)
# Note: you may need to restart the kernel to use updated packages.

# %%
import requests
import time

URL = "https://proof.ovh.net/files/1Gb.dat"

# Limit to approximately 4 MB/s
LIMIT_MBPS = 2
CHUNK_SIZE = 64 * 1024  # 64 KB

delay = CHUNK_SIZE / (LIMIT_MBPS * 1024 * 1024)

while True:
    try:
        print("Downloading...")
        with requests.get(URL, stream=True, timeout=10) as r:
            r.raise_for_status()

            for chunk in r.iter_content(chunk_size=CHUNK_SIZE):
                if not chunk:
                    break
                time.sleep(delay)

    except KeyboardInterrupt:
        print("Stopped.")
        break

    except Exception as e:
        print(f"Error: {e}")
        time.sleep(5)
# Out:
# Downloading...
# Error: HTTPSConnectionPool(host='proof.ovh.net', port=443): Read timed out.
# Downloading...
# Error: HTTPSConnectionPool(host='proof.ovh.net', port=443): Max retries exceeded with url: /files/1Gb.dat (Caused by ConnectTimeoutError(<urllib3.connection.HTTPSConnection object at 0x000001D2F9D1EC10>, 'Connection to proof.ovh.net timed out. (connect timeout=10)'))
# Downloading...
# Error: HTTPSConnectionPool(host='proof.ovh.net', port=443): Max retries exceeded with url: /files/1Gb.dat (Caused by ConnectTimeoutError(<urllib3.connection.HTTPSConnection object at 0x000001D2F9FD6D50>, 'Connection to proof.ovh.net timed out. (connect timeout=10)'))
# Downloading...
# Error: HTTPSConnectionPool(host='proof.ovh.net', port=443): Max retries exceeded with url: /files/1Gb.dat (Caused by ConnectTimeoutError(<urllib3.connection.HTTPSConnection object at 0x000001D2F9FD5BD0>, 'Connection to proof.ovh.net timed out. (connect timeout=10)'))
# Downloading...
# Error: HTTPSConnectionPool(host='proof.ovh.net', port=443): Max retries exceeded with url: /files/1Gb.dat (Caused by NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x000001D2F9FD60D0>: Failed to establish a new connection: [WinError 10053] An established connection was aborted by the software in your host machine'))
# Downloading...
# Error: HTTPSConnectionPool(host='proof.ovh.net', port=443): Max retries exceeded with url: /files/1Gb.dat (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x000001D2F9FD6990>: Failed to resolve 'proof.ovh.net' ([Errno 11001] getaddrinfo failed)"))
# Downloading...
